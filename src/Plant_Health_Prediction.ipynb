# %% [markdown]
# <a href="https://colab.research.google.com/github/derewor/Plant_Health_Prediction_Project/blob/main/src/Plant_Health_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_squared_error, classification_report, confusion_matrix, f1_score

# %%
# import the dataset
df = pd.read_csv('/content/plant_health_data.csv', delimiter=',')
df.head(2)
# Out:
#                     Timestamp  Plant_ID  Soil_Moisture  Ambient_Temperature  \
# 0  2024-10-03 10:54:53.407995         1      27.521109            22.240245
# 1  2024-10-03 16:54:53.407995         1      14.835566            21.706763
#
#    Soil_Temperature   Humidity  Light_Intensity   Soil_pH  Nitrogen_Level  \
# 0         21.900435  55.291904       556.172805  5.581955       10.003650
# 1         18.680892  63.949181       596.136721  7.135705       30.712562
#
#    Phosphorus_Level  Potassium_Level  Chlorophyll_Content  \
# 0         45.806852        39.076199            35.703006
# 1         25.394393        17.944826            27.993296
#
#    Electrochemical_Signal Plant_Health_Status
# 0                0.941402         High Stress
# 1                0.164899         High Stress

# %%
# The total number of rows and columns of the dataset
df.shape
# Out:
# (1200, 14)

# %%
# Check for datatypes and nullvalues of each column.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Timestamp               1200 non-null   object
#  1   Plant_ID                1200 non-null   int64
#  2   Soil_Moisture           1200 non-null   float64
#  3   Ambient_Temperature     1200 non-null   float64
#  4   Soil_Temperature        1200 non-null   float64
#  5   Humidity                1200 non-null   float64
#  6   Light_Intensity         1200 non-null   float64
#  7   Soil_pH                 1200 non-null   float64
#  8   Nitrogen_Level          1200 non-null   float64
#  9   Phosphorus_Level        1200 non-null   float64
#  10  Potassium_Level         1200 non-null   float64
#  11  Chlorophyll_Content     1200 non-null   float64
#  12  Electrochemical_Signal  1200 non-null   float64
#  13  Plant_Health_Status     1200 non-null   object
# dtypes: float64(11), int64(1), object(2)
# memory usage: 131.4+ KB

# %%
# how is the distribution of the data?
df.describe()
# Out:
#           Plant_ID  Soil_Moisture  Ambient_Temperature  Soil_Temperature  \
# count  1200.000000    1200.000000          1200.000000       1200.000000
# mean      5.500000      25.106918            23.999130         19.957794
# std       2.873479       8.677725             3.441561          2.932073
# min       1.000000      10.000724            18.001993         15.003710
# 25%       3.000000      17.131893            21.101766         17.353027
# 50%       5.500000      25.168333            23.889044         19.911473
# 75%       8.000000      32.370231            27.042634         22.596851
# max      10.000000      39.993164            29.990886         24.995929
#
#           Humidity  Light_Intensity      Soil_pH  Nitrogen_Level  \
# count  1200.000000      1200.000000  1200.000000     1200.000000
# mean     54.853165       612.637265     6.524102       30.106751
# std       8.784916       228.318853     0.581755       11.514396
# min      40.028758       200.615482     5.507392       10.003650
# 25%      47.019694       416.878983     6.026042       20.249774
# 50%      54.692069       617.240221     6.540524       30.138590
# 75%      62.451053       811.474690     7.030039       40.184737
# max      69.968871       999.856262     7.497823       49.951136
#
#        Phosphorus_Level  Potassium_Level  Chlorophyll_Content  \
# count       1200.000000      1200.000000          1200.000000
# mean          30.264484        30.112088            34.749591
# std           11.466846        11.668085             8.766995
# min           10.017690        10.000606            20.025511
# 25%           20.894445        19.585561            27.463350
# 50%           30.019385        30.495054            34.433427
# 75%           40.131459        40.108296            42.232637
# max           49.980700        49.981945            49.990811
#
#        Electrochemical_Signal
# count             1200.000000
# mean                 0.987764
# std                  0.575116
# min                  0.002376
# 25%                  0.487982
# 50%                  0.981647
# 75%                  1.473142
# max                  1.996116

# %% [markdown]
# The mean and the median are very close suggesting the good quality of the data.

# %%
num_features = [col for col in df.columns if col != 'Plant_ID' and col != 'Timestamp' and col != 'Plant_Health_Status']
num_features
# Out:
# ['Soil_Moisture',
#  'Ambient_Temperature',
#  'Soil_Temperature',
#  'Humidity',
#  'Light_Intensity',
#  'Soil_pH',
#  'Nitrogen_Level',
#  'Phosphorus_Level',
#  'Potassium_Level',
#  'Chlorophyll_Content',
#  'Electrochemical_Signal']

# %%
# what is the proportion of the three plant health categories.
df['Plant_Health_Status'].value_counts()
# Out:
# Plant_Health_Status
# High Stress        500
# Moderate Stress    401
# Healthy            299
# Name: count, dtype: int64

# %%
# plot the num_features to observe the distribution of the values
fig, axs = plt.subplots(3, 4, figsize=(12, 14))
axs = axs.flatten()

# Plot histograms for each column
for i, col in enumerate(num_features):
    axs[i].hist(df[col], bins=10, edgecolor='black')
    axs[i].set_xlabel(col)
    axs[i].set_ylabel('Counts')

# %%
plt.figure(figsize=(4,4))
sns.boxplot(df[['Humidity','Soil_pH','Light_Intensity','Phosphorus_Level']])
plt.xticks(rotation=45)
plt.show()

# %%
# Before spliting the data into train and test samples, convert the categorical variabe Plant_health_status
# into numerical.
phs_encoded = pd.get_dummies(df['Plant_Health_Status'])
phs_encoded = phs_encoded.apply(lambda row: row.map({True:1, False:0}) )
phs_encoded.head()
# Out:
#    Healthy  High Stress  Moderate Stress
# 0        0            1                0
# 1        0            1                0
# 2        0            1                0
# 3        0            1                0
# 4        0            1                0

# %%
# Merge the one-hot encoded categorical feature with num_features.
features = pd.concat([df[num_features], phs_encoded], axis=1)
features.head()
# Out:
#    Soil_Moisture  Ambient_Temperature  Soil_Temperature   Humidity  \
# 0      27.521109            22.240245         21.900435  55.291904
# 1      14.835566            21.706763         18.680892  63.949181
# 2      17.086362            21.180946         15.392939  67.837956
# 3      15.336156            22.593302         22.778394  58.190811
# 4      39.822216            28.929001         18.100937  63.772036
#
#    Light_Intensity   Soil_pH  Nitrogen_Level  Phosphorus_Level  \
# 0       556.172805  5.581955       10.003650         45.806852
# 1       596.136721  7.135705       30.712562         25.394393
# 2       591.124627  5.656852       29.337002         27.573892
# 3       241.412476  5.584523       16.966621         26.180705
# 4       444.493830  5.919707       10.944961         37.898907
#
#    Potassium_Level  Chlorophyll_Content  Electrochemical_Signal  Healthy  \
# 0        39.076199            35.703006                0.941402        0
# 1        17.944826            27.993296                0.164899        0
# 2        35.706530            43.646308                1.081728        0
# 3        26.257746            37.838095                1.186088        0
# 4        37.654483            48.265812                1.609805        0
#
#    High Stress  Moderate Stress
# 0            1                0
# 1            1                0
# 2            1                0
# 3            1                0
# 4            1                0

# %%
# STEP1. determine the numerical features and the target feature
X = df[num_features] # num_features
Y = df['Plant_Health_Status'] # target feature
class_names = Y.unique()
class_names
# Out:
# array(['High Stress', 'Moderate Stress', 'Healthy'], dtype=object)

# %%
# STEP 2. Split the features into train and test.
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42 )
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (960, 11)
# (240, 11)
# (960,)
# (240,)

# %%
# select and train a model.
model = RandomForestClassifier(random_state=42)
model.fit(X_train, Y_train)
y_pred = model.predict(X_test)
fittness = classification_report(Y_test, y_pred, target_names=class_names)
print(fittness)
# Out:
#                  precision    recall  f1-score   support
#
#     High Stress       1.00      1.00      1.00        65
# Moderate Stress       1.00      0.99      0.99        85
#         Healthy       0.99      1.00      0.99        90
#
#        accuracy                           1.00       240
#       macro avg       1.00      1.00      1.00       240
#    weighted avg       1.00      1.00      1.00       240

# %% [markdown]
# # The f1-score value shows that the model classified the individual rows perfectly. To show that the model is good for unseen data, a hypothetical data was generated.

# %%
df[num_features].describe().loc[['min', 'max']]
# Out:
#      Soil_Moisture  Ambient_Temperature  Soil_Temperature   Humidity  \
# min      10.000724            18.001993         15.003710  40.028758
# max      39.993164            29.990886         24.995929  69.968871
#
#      Light_Intensity   Soil_pH  Nitrogen_Level  Phosphorus_Level  \
# min       200.615482  5.507392       10.003650          10.01769
# max       999.856262  7.497823       49.951136          49.98070
#
#      Potassium_Level  Chlorophyll_Content  Electrochemical_Signal
# min        10.000606            20.025511                0.002376
# max        49.981945            49.990811                1.996116

# %%
# Generate a jypothetical data based on the min and max values of the original data to test the prediction.
Soil_Moisture = np.random.uniform(10, 40, 100)
Ambient_Temperature = np.random.uniform(18, 30, 100)
Soil_Temperature = np.random.uniform(15, 25, 100)
Humidity = np.random.uniform(40, 70, 100)
Light_Intensity = np.random.uniform(200, 1000, 100)
Soil_pH = np.random.uniform(5.5, 7.5, 100)
Nitrogen_Level = np.random.uniform(10, 50, 100)
Phosphorus_Level = np.random.uniform(10, 50, 100)
Potassium_Level = np.random.uniform(10, 50, 100)
Chlorophyll_Content = np.random.uniform(20, 50, 100)
Electrochemical_Signal = np.random.uniform(0, 2, 100)

# %%
# Create a dataframe from the hypothetical data above.
df_hypo = pd.DataFrame([Soil_Moisture,
                        Ambient_Temperature,
                        Soil_Temperature,
                        Humidity,
                        Light_Intensity,
                        Soil_pH,
                        Nitrogen_Level,
                        Phosphorus_Level,
                        Potassium_Level,
                        Chlorophyll_Content,
                        Electrochemical_Signal])

# %%
# The dataframe put the feature names in rows and need to be transposed.
df1 = df_hypo.T
df1.columns = ['Soil_Moisture',
               'Ambient_Temperature',
               'Soil_Temperature',
               'Humidity',
               'Light_Intensity',
               'Soil_pH',
               'Nitrogen_Level',
               'Phosphorus_Level',
               'Potassium_Level',
               'Chlorophyll_Content',
               'Electrochemical_Signal']
df1
# Out:
#     Soil_Moisture  Ambient_Temperature  Soil_Temperature   Humidity  \
# 0       34.986249            29.248079         19.348877  67.761859
# 1       19.952674            26.042509         24.049193  66.643071
# 2       35.975578            29.452233         16.209904  53.404760
# 3       38.339024            28.645460         21.063711  65.331483
# 4       24.210655            28.212456         15.919249  50.822121
# ..            ...                  ...               ...        ...
# 95      12.764912            27.031691         22.860414  67.117960
# 96      30.653008            28.447583         15.124570  65.351998
# 97      34.047424            21.279586         15.662842  67.684814
# 98      29.839241            26.706201         21.039351  60.138616
# 99      14.695916            21.170493         16.625806  42.256320
#
#     Light_Intensity   Soil_pH  Nitrogen_Level  Phosphorus_Level  \
# 0        898.373085  6.928979       39.699657         30.140687
# 1        589.448118  7.468055       35.196092         43.856484
# 2        927.174969  6.105284       49.214859         29.663441
# 3        288.233428  7.192614       41.004397         27.920066
# 4        670.666673  6.597740       30.542776         12.303832
# ..              ...       ...             ...               ...
# 95       996.131744  7.187404       39.286465         21.368377
# 96       414.484504  5.819318       18.255981         10.153190
# 97       811.851444  5.939401       29.471395         23.045950
# 98       396.904700  7.173348       38.558157         36.152008
# 99       917.085553  6.166339       28.455163         36.343588
#
#     Potassium_Level  Chlorophyll_Content  Electrochemical_Signal
# 0         39.284422            21.193581                0.608380
# 1         14.105623            39.617928                1.870419
# 2         47.924193            49.497454                1.509353
# 3         10.929024            26.633217                1.234483
# 4         29.345782            22.237633                1.406212
# ..              ...                  ...                     ...
# 95        31.199191            25.866935                0.277483
# 96        48.699662            35.685185                0.761550
# 97        25.663607            25.537951                0.712580
# 98        39.100489            23.214924                1.871923
# 99        40.524623            45.375182                0.279478
#
# [100 rows x 11 columns]

# %%
# Now based on the model fitted above classify the pehnotype of the 100 hypothetical plants grown on this field condition.
x_test = df1
y_hat = model.predict(x_test)
y_hat = pd.DataFrame(y_hat)
y_hat.value_counts()
# Out:
# 0
# High Stress        48
# Moderate Stress    30
# Healthy            22
# Name: count, dtype: int64

# %%
# Determine the probability of being true for each value
probabilities = model.predict_proba(x_test)
probabilities = pd.DataFrame(probabilities)
probabilities.columns = ['healthy', 'high_stress', 'moderate_stress']
prediction_probabilities = pd.concat([y_hat, probabilities], axis=1)
prediction_probabilities
# Out:
#                   0  healthy  high_stress  moderate_stress
# 0           Healthy     0.90         0.02             0.08
# 1       High Stress     0.06         0.71             0.23
# 2           Healthy     0.79         0.00             0.21
# 3           Healthy     0.75         0.05             0.20
# 4   Moderate Stress     0.10         0.04             0.86
# ..              ...      ...          ...              ...
# 95      High Stress     0.02         0.98             0.00
# 96  Moderate Stress     0.21         0.16             0.63
# 97          Healthy     0.95         0.01             0.04
# 98  Moderate Stress     0.16         0.02             0.82
# 99      High Stress     0.00         0.99             0.01
#
# [100 rows x 4 columns]

# %%
# How is the correlation between the num features?
corr = df[num_features].corr()
plt.figure(figsize=(8,10))
sns.heatmap(data=corr, annot=True, cmap='coolwarm', fmt='.2f')
plt.show()
